# %% [markdown]
# These datasets are hosted on: https://archive.ics.uci.edu/ml/datasets/Restaurant+%26+consumer+data
#
# They were originally published by: Blanca Vargas-Govea, Juan Gabriel González-Serna, Rafael Ponce-Medellín. Effects of relevant contextual features in the performance of a restaurant recommender system. In RecSys11: Workshop on Context Aware Recommender Systems (CARS-2011), Chicago, IL, USA, October 23, 2011.

# %% [markdown]
# # Making Recommendations Based on Correlation

# %%
import numpy as np
import pandas as pd

# %%
# rating_final.csv
url = 'https://drive.google.com/file/d/1ptu4AlEXO4qQ8GytxKHoeuS1y4l_zWkC/view?usp=sharing' 
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
frame = pd.read_csv(path)

# chefmozcuisine.csv
url = 'https://drive.google.com/file/d/1S0_EGSRERIkSKW4D8xHPGZMqvlhuUzp1/view?usp=sharing' 
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
cuisine = pd.read_csv(path)

# 'geoplaces2.csv'
url = 'https://drive.google.com/file/d/1ee3ib7LqGsMUksY68SD9yBItRvTFELxo/view?usp=sharing' 
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
geodata = pd.read_csv(path, encoding = 'CP1252') # change encoding to 'mbcs' in Windows

# %% [markdown]
# ### Preparing Data For Correlation

# %% [markdown]
# We will look for restaurants that are similar to the most popular restaurant from the last notebook "Tortas Locas Hipocampo". "Similarity" will be defined by how well other places correlate with "Tortas Locas" in the user-item matrix. In this matrix, we have all the users in the rows and all the restaurants in the columns. It has many NaNs because most of the time users have not visited many restaurants —we call this a sparse matrix.

# %%
pd.set_option("display.max_columns",None)
places_crosstab = pd.pivot_table(data=frame, values='rating', index='userID', columns='placeID')
places_crosstab.head(10)
# Out:
# placeID  132560  132561  132564  132572  132583  132584  132594  132608  \
# userID
# U1001       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1002       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1003       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1004       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1005       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1006       NaN     NaN     NaN     1.0     NaN     NaN     NaN     NaN
# U1007       NaN     NaN     NaN     1.0     NaN     NaN     NaN     NaN
# U1008       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1009       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1010       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# placeID  132609  132613  132626  132630  132654  132660  132663  132665  \
# userID
# U1001       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1002       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1003       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1004       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1005       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1006       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1007       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1008       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1009       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1010       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# placeID  132667  132668  132706  132715  132717  132723  132732  132733  \
# userID
# U1001       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1002       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1003       NaN     NaN     NaN     NaN     NaN     2.0     NaN     NaN
# U1004       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1005       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1006       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1007       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1008       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1009       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1010       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# placeID  132740  132754  132755  132766  132767  132768  132773  132825  \
# userID
# U1001       NaN     NaN     NaN     NaN     NaN     NaN     NaN     2.0
# U1002       NaN     NaN     NaN     NaN     NaN     NaN     NaN     2.0
# U1003       NaN     2.0     2.0     NaN     NaN     NaN     NaN     2.0
# U1004       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1005       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1006       NaN     NaN     NaN     NaN     NaN     NaN     NaN     1.0
# U1007       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1008       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1009       NaN     1.0     NaN     NaN     NaN     NaN     NaN     1.0
# U1010       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# placeID  132830  132834  132845  132846  132847  132851  132854  132856  \
# userID
# U1001       1.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1002       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1003       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1004       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1005       1.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1006       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1007       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1008       NaN     NaN     NaN     1.0     NaN     1.0     2.0     NaN
# U1009       NaN     2.0     NaN     NaN     NaN     NaN     NaN     NaN
# U1010       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# placeID  132858  132861  132862  132866  132869  132870  132872  132875  \
# userID
# U1001       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1002       NaN     NaN     2.0     NaN     NaN     NaN     NaN     NaN
# U1003       NaN     NaN     1.0     NaN     NaN     NaN     NaN     NaN
# U1004       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1005       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1006       NaN     NaN     NaN     NaN     NaN     NaN     NaN     2.0
# U1007       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1008       1.0     NaN     NaN     1.0     1.0     NaN     NaN     NaN
# U1009       NaN     NaN     2.0     NaN     NaN     NaN     NaN     NaN
# U1010       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# placeID  132877  132884  132885  132921  132922  132925  132937  132951  \
# userID
# U1001       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1002       NaN     NaN     NaN     2.0     NaN     1.0     NaN     NaN
# U1003       NaN     NaN     NaN     NaN     2.0     NaN     2.0     NaN
# U1004       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1005       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1006       NaN     2.0     NaN     NaN     2.0     NaN     NaN     NaN
# U1007       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1008       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1009       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1010       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# placeID  132954  132955  132958  134975  134976  134983  134986  134987  \
# userID
# U1001       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1002       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1003       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1004       2.0     2.0     2.0     NaN     NaN     NaN     NaN     NaN
# U1005       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1006       1.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1007       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1008       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1009       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1010       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# placeID  134992  134996  134999  135000  135001  135011  135013  135016  \
# userID
# U1001       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1002       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1003       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1004       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1005       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1006       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1007       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1008       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1009       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1010       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# placeID  135018  135019  135021  135025  135026  135027  135028  135030  \
# userID
# U1001       NaN     NaN     NaN     2.0     NaN     NaN     NaN     NaN
# U1002       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1003       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1004       NaN     NaN     NaN     NaN     NaN     NaN     2.0     NaN
# U1005       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1006       NaN     NaN     NaN     NaN     2.0     NaN     NaN     1.0
# U1007       NaN     NaN     NaN     1.0     NaN     NaN     NaN     NaN
# U1008       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1009       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1010       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# placeID  135032  135033  135034  135035  135038  135039  135040  135041  \
# userID
# U1001       NaN     1.0     NaN     NaN     NaN     1.0     1.0     NaN
# U1002       NaN     NaN     NaN     NaN     NaN     NaN     NaN     2.0
# U1003       NaN     NaN     NaN     NaN     NaN     NaN     NaN     0.0
# U1004       2.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1005       2.0     NaN     NaN     NaN     NaN     NaN     NaN     1.0
# U1006       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1007       1.0     NaN     NaN     NaN     1.0     NaN     NaN     NaN
# U1008       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1009       NaN     NaN     NaN     NaN     2.0     NaN     NaN     NaN
# U1010       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# placeID  135042  135043  135044  135045  135046  135047  135048  135049  \
# userID
# U1001       NaN     NaN     NaN     1.0     NaN     NaN     NaN     NaN
# U1002       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1003       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1004       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1005       2.0     0.0     NaN     NaN     NaN     NaN     NaN     NaN
# U1006       NaN     NaN     NaN     NaN     NaN     NaN     1.0     NaN
# U1007       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1008       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1009       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1010       2.0     NaN     NaN     NaN     NaN     1.0     NaN     NaN
#
# placeID  135050  135051  135052  135053  135054  135055  135057  135058  \
# userID
# U1001       NaN     1.0     NaN     NaN     NaN     NaN     NaN     NaN
# U1002       NaN     NaN     1.0     NaN     NaN     NaN     NaN     NaN
# U1003       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1004       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1005       1.0     NaN     NaN     NaN     NaN     NaN     1.0     NaN
# U1006       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1007       NaN     NaN     NaN     NaN     NaN     NaN     1.0     1.0
# U1008       NaN     NaN     NaN     NaN     1.0     NaN     NaN     NaN
# U1009       NaN     NaN     2.0     NaN     NaN     NaN     NaN     1.0
# U1010       NaN     NaN     NaN     1.0     NaN     NaN     NaN     1.0
#
# placeID  135059  135060  135062  135063  135064  135065  135066  135069  \
# userID
# U1001       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1002       1.0     NaN     1.0     NaN     NaN     NaN     NaN     NaN
# U1003       2.0     NaN     NaN     NaN     0.0     NaN     NaN     NaN
# U1004       NaN     1.0     2.0     NaN     NaN     NaN     NaN     NaN
# U1005       NaN     NaN     NaN     NaN     NaN     NaN     2.0     NaN
# U1006       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1007       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1008       NaN     NaN     NaN     NaN     NaN     NaN     NaN     1.0
# U1009       2.0     1.0     NaN     0.0     NaN     NaN     NaN     NaN
# U1010       NaN     NaN     NaN     NaN     0.0     1.0     NaN     NaN
#
# placeID  135070  135071  135072  135073  135074  135075  135076  135079  \
# userID
# U1001       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1002       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1003       NaN     NaN     NaN     NaN     NaN     2.0     NaN     2.0
# U1004       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1005       NaN     NaN     NaN     NaN     NaN     NaN     2.0     NaN
# U1006       NaN     NaN     NaN     NaN     NaN     1.0     NaN     1.0
# U1007       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1008       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1009       NaN     NaN     NaN     NaN     NaN     NaN     NaN     1.0
# U1010       NaN     NaN     NaN     NaN     NaN     NaN     1.0     0.0
#
# placeID  135080  135081  135082  135085  135086  135088  135104  135106  \
# userID
# U1001       NaN     NaN     NaN     0.0     NaN     NaN     NaN     NaN
# U1002       NaN     NaN     NaN     1.0     NaN     NaN     NaN     1.0
# U1003       2.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1004       NaN     NaN     NaN     NaN     NaN     NaN     NaN     2.0
# U1005       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1006       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1007       NaN     NaN     NaN     1.0     0.0     NaN     NaN     NaN
# U1008       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1009       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# U1010       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# placeID  135108  135109
# userID
# U1001       NaN     NaN
# U1002       NaN     NaN
# U1003       NaN     NaN
# U1004       NaN     NaN
# U1005       NaN     NaN
# U1006       NaN     NaN
# U1007       1.0     NaN
# U1008       1.0     NaN
# U1009       NaN     NaN
# U1010       NaN     NaN

# %% [markdown]
# Let's look at the users that have visited "Tortas Locas":

# %%
# Tortas Locas
top_popular_placeID = 135085

# %%
Tortas_ratings = places_crosstab[top_popular_placeID]
Tortas_ratings[Tortas_ratings>=0] # exclude NaNs
# Out:
# userID
# U1001    0.0
# U1002    1.0
# U1007    1.0
# U1013    1.0
# U1016    2.0
# U1027    1.0
# U1029    1.0
# U1032    1.0
# U1033    2.0
# U1036    2.0
# U1045    2.0
# U1046    1.0
# U1049    0.0
# U1056    2.0
# U1059    2.0
# U1062    0.0
# U1077    2.0
# U1081    1.0
# U1084    2.0
# U1086    2.0
# U1089    1.0
# U1090    2.0
# U1092    0.0
# U1098    1.0
# U1104    2.0
# U1106    2.0
# U1108    1.0
# U1109    2.0
# U1113    1.0
# U1116    2.0
# U1120    0.0
# U1122    2.0
# U1132    2.0
# U1134    2.0
# U1135    0.0
# U1137    2.0
# Name: 135085, dtype: float64

# %% [markdown]
# ## Evaluating Similarity Based on Correlation
#
# Now we will look at how well other restaurants correlate with Tortas Locas. A strong positive correlation between two restaurants indicates that users who liked one restaruant also liked the other. A negative correlation would mean that users who liked one restaurant did not like the other. So, we will look for strong, positive correlations to find similar restaurants.

# %%
# we get warnings because computing the pearson correlation coefficient with NaNs, but the results are still ok
similar_to_Tortas = places_crosstab.corrwith(Tortas_ratings)
similar_to_Tortas
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py:2683: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py:2542: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# placeID
# 132560         NaN
# 132561         NaN
# 132564         NaN
# 132572   -0.428571
# 132583         NaN
#             ...
# 135088         NaN
# 135104         NaN
# 135106    0.454545
# 135108         NaN
# 135109         NaN
# Length: 130, dtype: float64

# %% [markdown]
# Many restuarants get a NaN, because there are no users that went to both that restaurant _and_ Tortas Locas. But some of them give us a correlation score. Let's drop NaNs and look at the valid results:

# %%
corr_Tortas = pd.DataFrame(similar_to_Tortas, columns=['PearsonR'])
corr_Tortas.dropna(inplace=True)
corr_Tortas.head(12)
# Out:
#          PearsonR
# placeID
# 132572  -0.428571
# 132723   0.301511
# 132754   0.930261
# 132825   0.700745
# 132834   0.814823
# 132856   0.475191
# 132861   0.500000
# 132862   0.559017
# 132872   0.840168
# 132921   0.493013
# 132922   1.000000
# 132925   1.000000

# %% [markdown]
# Some correlations are a perfect 1. It is possible that this is because very few users went to both that restaurant and "Tortas Locas" (also because there are very few rating options, only 0, 1 and 2).

# %%
rating = pd.DataFrame(frame.groupby('placeID')['rating'].mean())
rating['rating_count'] = frame.groupby('placeID')['rating'].count()
rating
# Out:
#            rating  rating_count
# placeID
# 132560   0.500000             4
# 132561   0.750000             4
# 132564   1.250000             4
# 132572   1.000000            15
# 132583   1.000000             4
# ...           ...           ...
# 135088   1.000000             6
# 135104   0.857143             7
# 135106   1.200000            10
# 135108   1.181818            11
# 135109   1.000000             4
#
# [130 rows x 2 columns]

# %%
Tortas_corr_summary = corr_Tortas.join(rating['rating_count'])
Tortas_corr_summary.drop(top_popular_placeID, inplace=True) # drop Tortas Locas itself
Tortas_corr_summary
# Out:
#          PearsonR  rating_count
# placeID
# 132572  -0.428571            15
# 132723   0.301511            12
# 132754   0.930261            13
# 132825   0.700745            32
# 132834   0.814823            25
# 132856   0.475191            14
# 132861   0.500000             7
# 132862   0.559017            18
# 132872   0.840168            12
# 132921   0.493013            17
# 132922   1.000000             6
# 132925   1.000000             5
# 132937   1.000000             4
# 132951   0.416667            10
# 135025  -0.084215            15
# 135026   0.000000            11
# 135027   0.408248             8
# 135028   0.892218            15
# 135030   0.654654            12
# 135032   0.342475            28
# 135038   0.831513            24
# 135039   0.090909            12
# 135041   0.643796            17
# 135042   0.881409            20
# 135044   0.500000             4
# 135045   0.912871            13
# 135046   0.867722            11
# 135047   0.000000            10
# 135051   0.710047            14
# 135052   0.741825            25
# 135053   1.000000             8
# 135057  -0.500000            15
# 135058   0.292174            18
# 135059   0.000000             9
# 135060   0.342381            22
# 135062   0.898933            21
# 135063   0.866025             8
# 135064   0.166667            17
# 135065  -0.375000             9
# 135066   1.000000            12
# 135072   0.500000             8
# 135076   1.000000            13
# 135079   0.399012            17
# 135106   0.454545            10

# %% [markdown]
# Let's filter out restaurants with a rating count below 10.
#
# Then, take the top 10 restaurants in terms of similarity to Tortas:

# %%
top10 = Tortas_corr_summary[Tortas_corr_summary['rating_count']>=10].sort_values('PearsonR', ascending=False).head(10)
top10
# Out:
#          PearsonR  rating_count
# placeID
# 135076   1.000000            13
# 135066   1.000000            12
# 132754   0.930261            13
# 135045   0.912871            13
# 135062   0.898933            21
# 135028   0.892218            15
# 135042   0.881409            20
# 135046   0.867722            11
# 132872   0.840168            12
# 135038   0.831513            24

# %%
places =  geodata[['placeID', 'name']]
places
# Out:
#      placeID                            name
# 0     134999                 Kiku Cuernavaca
# 1     132825                 puesto de tacos
# 2     135106      El Rincón de San Francisco
# 3     132667  little pizza Emilio Portes Gil
# 4     132613                   carnitas_mata
# ..       ...                             ...
# 125   132866                         Chaires
# 126   135072                      Sushi Itto
# 127   135109                       Paniroles
# 128   135019     Restaurant Bar Coty y Pablo
# 129   132877                sirloin stockade
#
# [130 rows x 2 columns]

# %%
top10 = top10.merge(places, left_index=True, right_on="placeID")
top10
# Out:
#      PearsonR  rating_count  placeID                           name
# 13   1.000000            13   135076      Restaurante Pueblo Bonito
# 52   1.000000            12   135066             Restaurante Guerra
# 117  0.930261            13   132754                Cabana Huasteca
# 28   0.912871            13   135045        Restaurante la Gran Via
# 113  0.898933            21   135062  Restaurante El Cielo Potosino
# 120  0.892218            15   135028                    La Virreina
# 25   0.881409            20   135042    Restaurant Oriental Express
# 42   0.867722            11   135046        Restaurante El Reyecito
# 90   0.840168            12   132872                Pizzeria Julios
# 60   0.831513            24   135038          Restaurant la Chalita

# %% [markdown]
# Let's look at the cuisine type (some restaurants do not have a cuisine type... but for the ones that do, here it is):

# %%
top10.merge(cuisine)
# Out:
#    PearsonR  rating_count  placeID                         name   Rcuisine
# 0  0.930261            13   132754              Cabana Huasteca    Mexican
# 1  0.892218            15   135028                  La Virreina    Mexican
# 2  0.881409            20   135042  Restaurant Oriental Express    Chinese
# 3  0.867722            11   135046      Restaurante El Reyecito  Fast_Food
# 4  0.840168            12   132872              Pizzeria Julios   American

# %% [markdown]
# ## Challenge:
#
# Create a function that takes as input a restaurant id and a number (n), and outputs the names of the top n most similar restuarants to the inputed one.
#
# You can assume that the user-item matrix (places_crosstab) is already created.

# %%
# your code here
def top_n_rest(rest_id, n):
    rest_ratings = places_crosstab[rest_id]
    similar_to_rest = places_crosstab.corrwith(rest_ratings)
    corr_rest = pd.DataFrame(similar_to_Tortas, columns=['PearsonR'])
    corr_rest.dropna(inplace=True)
    rest_corr_summary = corr_rest.join(rating['rating_count'])
    rest_corr_summary.drop(rest_id, inplace=True) # drop the inputed restaurant itself
    top10 = rest_corr_summary[rest_corr_summary['rating_count']>=10].sort_values('PearsonR', ascending=False).head(n)
    top10 = top10.merge(places, left_index=True, right_on="placeID")
    return top10["name"]

# %%
top_n_rest(132754,10)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py:2683: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py:2542: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# 13         Restaurante Pueblo Bonito
# 121           Tortas Locas Hipocampo
# 52                Restaurante Guerra
# 28           Restaurante la Gran Via
# 113    Restaurante El Cielo Potosino
# 120                      La Virreina
# 25       Restaurant Oriental Express
# 42           Restaurante El Reyecito
# 90                   Pizzeria Julios
# 60             Restaurant la Chalita
# Name: name, dtype: object

# %%
def item_cor(item_id,n):
  restaurant_ratings = places_crosstab[item_id]
  similar_to_item = places_crosstab.corrwith(restaurant_ratings)
  corr_restautant = pd.DataFrame(similar_to_item, columns=['PearsonR'])
  corr_restautant.dropna(inplace=True)  
  rating = pd.DataFrame(frame.groupby('placeID')['rating'].mean())
  rating['rating_count'] = frame.groupby('placeID')['rating'].count()
  restaurant_corr_summary = corr_restautant.join(rating['rating_count'])
  restaurant_corr_summary.drop(item_id, inplace=True)
  top_n = restaurant_corr_summary[restaurant_corr_summary['rating_count']>=10].sort_values('PearsonR', ascending=False).head(10)
  top_n= top_n.merge(places, left_index=True, right_on="placeID")
  return top_n["name"]

# %%
item_cor(132754,10)
# Out:
# 62          Gordas de morales
# 75                       VIPS
# 121    Tortas Locas Hipocampo
# 90            Pizzeria Julios
# 116      Restaurante Tiberius
# 37                 Koye Sushi
# 1             puesto de tacos
# 80        Gorditas Doa Gloria
# 120               La Virreina
# 60      Restaurant la Chalita
# Name: name, dtype: object

# %% [markdown]
# ### BONUS (Next iteration)
# Instead of flitering out restaurants with a rating count below 10, let's consider a restaurant X as similar to Y only if at least 3 users have gone to both X and Y.
#
# i.e. user 143, 153, and 168 went to both restaurants - not 3 random users visited X, and a different 3 random users visited y

# %%
# your code here
def top_n_rest(rest_id, n):
    matching_three_users = places_crosstab.loc[places_crosstab[rest_id].notna(), :]
    matching_three_users = matching_three_users.loc[:, matching_three_users.notna().sum() >= 3]
    rest_ratings = matching_three_users[rest_id]
    similar_to_rest = places_crosstab.corrwith(rest_ratings)
    corr_rest = pd.DataFrame(similar_to_Tortas, columns=['PearsonR'])
    corr_rest.dropna(inplace=True)
    rest_corr_summary = corr_rest.join(rating['rating_count'])
    rest_corr_summary.drop(rest_id, inplace=True) # drop the inputed restaurant itself
    top10 = rest_corr_summary[rest_corr_summary['rating_count']>=10].sort_values('PearsonR', ascending=False).head(n)
    top10 = top10.merge(places, left_index=True, right_on="placeID")
    return list(top10["name"])

# %%
top_n_rest(135085,5)
# Out:
# 13         Restaurante Pueblo Bonito
# 52                Restaurante Guerra
# 117                  Cabana Huasteca
# 28           Restaurante la Gran Via
# 113    Restaurante El Cielo Potosino
# Name: name, dtype: object
